# %%
import numpy as np
import math

# %%
scores = [1.0, 2.0, 3.0]

def softmax(x):
  e_xi = sum([math.exp(i) for i in x]) 
  return [i/e_xi for i in x]
  
softmaxscore = softmax(scores)
print(softmaxscore)
# Out:
# [0.033120396946264216, 0.06624079389252843, 0.09936119083879263]
